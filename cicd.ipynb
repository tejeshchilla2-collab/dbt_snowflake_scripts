# %%
import requests

url = "https://api.thecatapi.com/v1/images/search?limit=10"
response = requests.get(url)
data = response.json()
table_name = "cat_images"
spark.createDataFrame(data).write.mode("append").saveAsTable(table_name)

# %%
# %sql
select * from cat_images
